# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd

# %%
path_to_usertrack = '/content/gdrive/MyDrive/adaptive-recommedation-system/nowplayingrs/nowplaying_rs_dataset/user_track_hashtag_timestamp.csv'
path_to_trainSEQ = '/content/gdrive/MyDrive/adaptive-recommedation-system/Train-Test Splits/Sequence/train_SEQ.csv'
path_to_train = '/content/gdrive/MyDrive/adaptive-recommedation-system/Train-Test Splits/Context/train.csv'
path_to_context_content = '/content/gdrive/MyDrive/adaptive-recommedation-system/nowplayingrs/nowplaying_rs_dataset/context_content_features.csv'
path_to_sentiment = '/content/gdrive/MyDrive/adaptive-recommedation-system/nowplayingrs/nowplaying_rs_dataset/sentiment_values.csv'

# %%
usertrack_df = pd.read_csv(path_to_usertrack)
trainSEQ_df = pd.read_csv(path_to_trainSEQ)
train_df = pd.read_csv(path_to_train)
content_context_df = pd.read_csv(path_to_context_content)
sentiment_df = pd.read_csv(path_to_sentiment)

# %%
sentiment_df
# Out:
#                                hashtag   vader_min   vader_max   vader_sum  \
# relaxtime         0.8 0.8 2.4     0.80         NaN         NaN         NaN
# melovechilicheese 0.8 0.8 0.8     0.80         NaN         NaN         NaN
# greatmusic        0.8 0.8 2.4     0.80         1.0         1.0         1.0
# rockballad        0.7 0.7 0.7     0.70         NaN         NaN         NaN
# amonamarth        0.3 0.3 0.3     0.30         NaN         NaN         NaN
# ...                                ...         ...         ...         ...
# posoye            NaN NaN NaN      NaN         NaN         NaN         NaN
# pulpfiction       NaN NaN NaN      NaN         NaN         NaN         NaN
# comedown          0.3 0.6 1.8     0.45         NaN         NaN         NaN
# hiddengems        NaN NaN NaN      NaN         NaN         NaN         NaN
# moderncountry     NaN NaN NaN      NaN         NaN         NaN         NaN
#
# ...

# %%
usertrack_df
# Out:
#              user_id                          track_id     hashtag  \
# 0           81496937  cd52b3e5b51da29e5893dba82a418a4b  nowplaying
# 1           81496937  cd52b3e5b51da29e5893dba82a418a4b        goth
# 2           81496937  cd52b3e5b51da29e5893dba82a418a4b   deathrock
# 3           81496937  cd52b3e5b51da29e5893dba82a418a4b    postpunk
# 4         2205686924  da3110a77b724072b08f231c9d6f7534  NowPlaying
# ...              ...                               ...         ...
# 17560108  2819332208  03498f305040835c5f76d7c5660204a2  nowplaying
# 17560109   154070865  8bacefe018a221d933529dd466e7c1c0  nowplaying
# 17560110   985591650  0e64c11b9a77e93f343f9c1c0cdbcf54  nowplaying
# 17560111    15518784  af5c5f220e0a872ac129f4f88b3db5f9  nowplaying
# 17560112    15518784  af5c5f220e0a872ac129f4f88b3db5f9  listenlive
#
#                    created_at
# 0         2014-01-01 05:54:21
# 1         2014-01-01 05:54:21
# 2         2014-01-01 05:54:21
# 3         2014-01-01 05:54:21
# ...

# %%
trainSEQ_df
# Out:
#            user_id                          track_id                hashtag  \
# 0        823214346  64b30f6ac1acecb7cef9dc890e1c3ea7                 kiss92
# 1        823214346  cc1a46ee0446538ecf6b65db01c30cd8                 kiss92
# 2        823214346  dbbd8525c1bc48cc791bfe618b74bac6                 kiss92
# 3        823214346  dbdbb866939c1ab1dfd0d5cfac740eaa                 kiss92
# 4        823214346  156523fa722ca14df9053e17cd7c2641                 kiss92
# ...            ...                               ...                    ...
# 253025  1610440242  aa34490291b260748548010757cfa40e  whythehellareyousosad
# 253026   188664895  6ff37834cc2f2c83afe9fc74fd6d199e     redhotchilipeppers
# 253027  2249784332  5af2fab63d9bffef342374b4595cdb42                tophits
# 253028   124052165  9615e2e8d36860706822c96fc368e483                 slayer
# 253029   956491087  02e062f570a94cad2dbff4a59696f391             goodsounds
#
#                  created_at     score lang tweet_lang  \
# ...

# %%
trainSEQ_df.track_id.nunique()
# Out:
# 20631

# %%
trainSEQ_df.rating.unique()
# Out:
# array([1])

# %%
train_df
# Out:
#            user_id                          track_id  hashtag  \
# 0        823214346  b129f3e0a0bdc1e61c57ce994f9d2932   kiss92
# 1        823214346  64b30f6ac1acecb7cef9dc890e1c3ea7   kiss92
# 2        823214346  cc1a46ee0446538ecf6b65db01c30cd8   kiss92
# 3        823214346  dbbd8525c1bc48cc791bfe618b74bac6   kiss92
# 4        823214346  dbdbb866939c1ab1dfd0d5cfac740eaa   kiss92
# ...            ...                               ...      ...
# 257007   231459661  1678afdba9516e1e7953970727566734       xx
# 257008    18976567  65ccf7984dcfeeee73cdf83f7a45a74d   smooth
# 257009   393147908  cd4658a9df4f8a9d73a1eab496edda25    bless
# 257010    25063433  e4a12a439cf826740e857198ec13a16d  classic
# 257011  2371920928  03e1eef3031e0cad064047bae3091194      lol
#
#                  created_at     score lang tweet_lang  \
# 0       2014-01-01 05:59:38  0.800000   en         en
# 1       2014-01-01 06:06:15  0.800000   en         en
# 2       2014-01-01 06:11:07  0.800000   en         en
# ...

# %%
content_context_df
# Out:
#          coordinates  instrumentalness  liveness  speechiness  danceability  \
# 0                NaN          0.004790    0.1800       0.0294         0.634
# 1                NaN          0.017700    0.0638       0.0624         0.769
# 2                NaN          0.000000    0.0860       0.0436         0.675
# 3                NaN          0.000000    0.1430       0.0292         0.324
# 4                NaN          0.000183    0.3620       0.0524         0.767
# ...              ...               ...       ...          ...           ...
# 11614666         NaN          0.000000    0.1220       0.1380         0.758
# 11614667         NaN          0.000107    0.1680       0.0291         0.626
# 11614668         NaN          0.000000    0.0892       0.0378         0.375
# 11614669         NaN          0.000679    0.0836       0.0296         0.312
# 11614670         NaN          0.002170    0.0504       0.0299         0.377
#
# ...
