# %% [markdown]
# # libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
path_to_usertrack_data = '/content/gdrive/MyDrive/adaptive-recommedation-system/nowplayingrs/nowplaying_rs_dataset/user_track_hashtag_timestamp.csv'

# %%
data = pd.read_csv(path_to_usertrack_data)

# %%
data
# Out:
#              user_id                          track_id     hashtag  \
# 0           81496937  cd52b3e5b51da29e5893dba82a418a4b  nowplaying
# 1           81496937  cd52b3e5b51da29e5893dba82a418a4b        goth
# 2           81496937  cd52b3e5b51da29e5893dba82a418a4b   deathrock
# 3           81496937  cd52b3e5b51da29e5893dba82a418a4b    postpunk
# 4         2205686924  da3110a77b724072b08f231c9d6f7534  NowPlaying
# ...              ...                               ...         ...
# 17560108  2819332208  03498f305040835c5f76d7c5660204a2  nowplaying
# 17560109   154070865  8bacefe018a221d933529dd466e7c1c0  nowplaying
# 17560110   985591650  0e64c11b9a77e93f343f9c1c0cdbcf54  nowplaying
# 17560111    15518784  af5c5f220e0a872ac129f4f88b3db5f9  nowplaying
# 17560112    15518784  af5c5f220e0a872ac129f4f88b3db5f9  listenlive
#
#                    created_at
# 0         2014-01-01 05:54:21
# 1         2014-01-01 05:54:21
# 2         2014-01-01 05:54:21
# 3         2014-01-01 05:54:21
# 4         2014-01-01 05:54:22
# ...                       ...
# 17560108  2014-12-23 07:21:04
# 17560109  2014-12-23 07:21:07
# 17560110  2014-12-23 07:21:08
# 17560111  2014-12-23 07:21:11
# 17560112  2014-12-23 07:21:11
#
# [17560113 rows x 4 columns]

# %% [markdown]
# # parsing the data

# %%
# convert created_at to datetime object and unix timestamp

data['created_at'] = pd.to_datetime(data['created_at'])

# %%
data['timestamp'] = (data['created_at'] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s')

# %%
data
# Out:
#              user_id                          track_id     hashtag  \
# 0           81496937  cd52b3e5b51da29e5893dba82a418a4b  nowplaying
# 1           81496937  cd52b3e5b51da29e5893dba82a418a4b        goth
# 2           81496937  cd52b3e5b51da29e5893dba82a418a4b   deathrock
# 3           81496937  cd52b3e5b51da29e5893dba82a418a4b    postpunk
# 4         2205686924  da3110a77b724072b08f231c9d6f7534  NowPlaying
# ...              ...                               ...         ...
# 17560108  2819332208  03498f305040835c5f76d7c5660204a2  nowplaying
# 17560109   154070865  8bacefe018a221d933529dd466e7c1c0  nowplaying
# 17560110   985591650  0e64c11b9a77e93f343f9c1c0cdbcf54  nowplaying
# 17560111    15518784  af5c5f220e0a872ac129f4f88b3db5f9  nowplaying
# 17560112    15518784  af5c5f220e0a872ac129f4f88b3db5f9  listenlive
#
#                   created_at   timestamp
# 0        2014-01-01 05:54:21  1388555661
# 1        2014-01-01 05:54:21  1388555661
# 2        2014-01-01 05:54:21  1388555661
# 3        2014-01-01 05:54:21  1388555661
# 4        2014-01-01 05:54:22  1388555662
# ...                      ...         ...
# 17560108 2014-12-23 07:21:04  1419319264
# 17560109 2014-12-23 07:21:07  1419319267
# 17560110 2014-12-23 07:21:08  1419319268
# 17560111 2014-12-23 07:21:11  1419319271
# 17560112 2014-12-23 07:21:11  1419319271
#
# [17560113 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17560113 entries, 0 to 17560112
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     int64
#  1   track_id    object
#  2   hashtag     object
#  3   created_at  datetime64[ns]
#  4   timestamp   int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 669.9+ MB

# %% [markdown]
# # feature engineering

# %% [markdown]
# ### Time-decay function definition
#
# This function will serve to establish a weight on recent interactions using exponential decay function, given as;
#
# $$w(t) = e^{^{-\lambda(t - t_0)}}.$$
#
# where, **w(t)** is the weight at time **t, t_0** is the current time, and **λ** is the decay rate.

# %%
## getting current time, assuming it's the latest timestamp from the data - t0
current_time = data['timestamp'].max()

# setting the decay rate - lamda λ
decay_rate = 0.001

# the time-decay funtion
def time_decay(timestamps, current_time, decay_rate):
  return np.exp(-decay_rate * (current_time - timestamps))

# %%
data['decay_weight'] = time_decay(data['timestamp'], current_time, decay_rate)

# %%
data.tail()
# Out:
#              user_id                          track_id     hashtag  \
# 17560108  2819332208  03498f305040835c5f76d7c5660204a2  nowplaying
# 17560109   154070865  8bacefe018a221d933529dd466e7c1c0  nowplaying
# 17560110   985591650  0e64c11b9a77e93f343f9c1c0cdbcf54  nowplaying
# 17560111    15518784  af5c5f220e0a872ac129f4f88b3db5f9  nowplaying
# 17560112    15518784  af5c5f220e0a872ac129f4f88b3db5f9  listenlive
#
#                   created_at   timestamp  decay_weight
# 17560108 2014-12-23 07:21:04  1419319264      0.993024
# 17560109 2014-12-23 07:21:07  1419319267      0.996008
# 17560110 2014-12-23 07:21:08  1419319268      0.997004
# 17560111 2014-12-23 07:21:11  1419319271      1.000000
# 17560112 2014-12-23 07:21:11  1419319271      1.000000

# %% [markdown]
# ### Time-decay weight application

# %%
# from related data, the explicit interaction value (which was rating) is 1 for each, we'll use it to multiply our decay weight

data['weighted_interaction'] = data['decay_weight'] * 1

# %%
data.tail()
# Out:
#              user_id                          track_id     hashtag  \
# 17560108  2819332208  03498f305040835c5f76d7c5660204a2  nowplaying
# 17560109   154070865  8bacefe018a221d933529dd466e7c1c0  nowplaying
# 17560110   985591650  0e64c11b9a77e93f343f9c1c0cdbcf54  nowplaying
# 17560111    15518784  af5c5f220e0a872ac129f4f88b3db5f9  nowplaying
# 17560112    15518784  af5c5f220e0a872ac129f4f88b3db5f9  listenlive
#
#                   created_at   timestamp  decay_weight  weighted_interaction
# 17560108 2014-12-23 07:21:04  1419319264      0.993024              0.993024
# 17560109 2014-12-23 07:21:07  1419319267      0.996008              0.996008
# 17560110 2014-12-23 07:21:08  1419319268      0.997004              0.997004
# 17560111 2014-12-23 07:21:11  1419319271      1.000000              1.000000
# 17560112 2014-12-23 07:21:11  1419319271      1.000000              1.000000

# %% [markdown]
# ### Interaction matrix
#
# This is the user-to-item matrix, as `users(user_id)` on the rows, `item(track_id)` on the columns, and then feature cells containing the `weighted_interactions`

# %%
# interaction_matrix = data.pivot_table(index='user_id', columns='track_id', values='weighted_interaction', fill_value=0)

# %% [markdown]
# due to inefficient memory and GPU, I'll be using a sparse matrix representation with SciPy

# %%
from scipy.sparse import csr_matrix

# %%
# creating a sparse matrix from the dataset
user_ids = data['user_id'].astype('category').cat.codes
track_ids = data['track_id'].astype('category').cat.codes

sparse_interaction_matrix = csr_matrix((data['weighted_interaction'], (user_ids, track_ids)))

# %%
# matrix shape will be by (number of users, number of tracks)
print(sparse_interaction_matrix)
# Out:
#   (0, 237753)	0.0
#   (1, 68886)	0.0
#   (1, 342349)	0.0
#   (2, 8806)	0.0
#   (2, 16896)	0.0
#   (2, 18493)	0.0
#   (2, 23231)	0.0
#   (2, 26298)	0.0
#   (2, 48655)	0.0
#   (2, 70991)	0.0
#   (2, 80499)	0.0
#   (2, 82544)	0.0
#   (2, 152652)	0.0
#   (2, 189249)	0.0
#   (2, 203266)	0.0
#   (2, 216217)	0.0
#   (2, 229388)	0.0
#   (2, 240076)	0.0
#   (2, 241284)	0.0
#   (2, 253737)	0.0
#   (2, 284627)	0.0
#   (3, 339042)	0.0
#   (4, 5077)	0.0
#   (4, 12515)	0.0
#   (4, 13541)	0.0
#   :	:
#   (138217, 327963)	7.454176694349057e-25
#   (138218, 119051)	6.111407515426417e-53
#   (138218, 316430)	3.392485092637685e-83
#   (138219, 16682)	1.3065532103069673e-81
#   (138220, 32629)	1.0757171486667669e-135
#   (138220, 58041)	2.3080487282943027e-134
#   (138220, 69959)	9.639610622923227e-169
#   (138220, 109913)	1.7845547198195654e-96
#   (138220, 119699)	1.7337676651169857e-74
#   (138220, 126709)	1.2338726759101766e-137
#   (138220, 139971)	2.8858438942955707e-133
#   (138220, 151874)	1.611607737115131e-132
#   (138220, 155890)	5.186850617598935e-72
#   (138220, 159393)	2.872824301318914e-168
#   (138220, 168000)	9.340898634926762e-134
#   (138220, 176433)	1.7967087331094132e-70
#   (138220, 204689)	7.85698119828768e-134
#   (138220, 226363)	6.95385111237901e-168
#   (138220, 237595)	7.307359379843233e-75
#   (138220, 242878)	1.7294740902311e-133
#   (138220, 253740)	1.2831229120600543e-74
#   (138220, 266761)	5.560804728762686e-138
#   (138220, 296824)	1.412558305196971e-134
#   (138221, 143870)	1.349642500176042e-51
#   (138222, 16085)	3.67054118635281e-98

# %% [markdown]
# ## model building
#
# * **selection:** for this **TDCF**, a matrix factorization model is used, one which can handle sparse matrices:
#
#     * TruncatedSVD: *Truncated Singular Value Decomposition*

# %%
from sklearn.decomposition import TruncatedSVD
import random

# %%
# TRAINING THE MODEL (sparse matrix)

# latent factors
n_components = 20

# training
model = TruncatedSVD(n_components=n_components)
model.fit(sparse_interaction_matrix)

# matrix transfomation
lower_dimensional_features = model.transform(sparse_interaction_matrix)

# %%
sparse_interaction_matrix
# Out:
# <138223x344536 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3017064 stored elements in Compressed Sparse Row format>

# %%
lower_dimensional_features
# Out:
# array([[ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000],
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000],
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000],
#        ...,
#        [ 2.34924591e-089, -6.88529057e-090,  1.30689726e-088, ...,
#          1.76334999e-085, -1.18502016e-085, -6.58265983e-087],
#        [ 5.96470322e-143,  1.96391313e-140,  3.73444805e-140, ...,
#          1.28856602e-137,  8.14215051e-139, -2.94278380e-138],
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000]])

# %% [markdown]
# # Recommendation Generation

# %%
from sklearn.metrics.pairwise import cosine_similarity

# using cosine similarity to compute item(track)
track_similarity = cosine_similarity(lower_dimensional_features.T)

# getting recommendation function for a user
def get_recommendations(track_id, similarity_matrix, k=5):
  # similariy scores for a specific track with all tracks
  similarity_scores = list(enumerate(similarity_matrix[track_id]))

  # sort tracks
  similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

  # the score of k most similar track
  most_similar_tracks = similarity_scores[1:k+1]

  # get track ID
  track_ids = [track[0] for track in most_similar_tracks]

  return track_ids

# %% [markdown]
# get recommendation for an item

# %%
recommended_track_ids = get_recommendations(10, track_similarity)
print(recommended_track_ids)
# Out:
# [8, 14, 18, 2, 3]

# %%
track_similarity
# Out:
# array([[ 1.00000000e+00,  2.51664775e-15, -4.95628737e-18,
#         -1.07291246e-17, -1.57577430e-17,  3.43485537e-18,
#          2.24762741e-18,  6.07555073e-18,  9.77615957e-19,
#         -2.56611868e-18,  5.41268488e-18,  6.61143461e-18,
#         -8.03606730e-18, -2.87270573e-19, -9.45588994e-18,
#         -5.91701317e-19,  9.16870979e-19, -8.70382974e-18,
#          1.02238837e-17, -2.85556644e-18],
#        [ 2.51664775e-15,  1.00000000e+00,  9.37971765e-17,
#          6.55874388e-16, -5.15250981e-16,  4.24761539e-16,
#         -5.58871726e-16,  6.48378254e-16,  1.56167180e-18,
#          3.52322036e-17,  4.19028045e-17, -1.89779195e-17,
#         -2.14082263e-17,  1.32186544e-17,  9.84460028e-19,
#         -8.88288223e-18, -1.28087483e-18, -3.15582871e-17,
#         -4.14971980e-18, -1.50608918e-17],
#        [-4.95628737e-18,  9.37971765e-17,  1.00000000e+00,
#          8.18227055e-16,  1.24805874e-15, -6.74104899e-16,
#         -7.32352285e-16,  1.08098418e-16,  2.13749445e-16,
#         -3.94504740e-16,  1.47922859e-16, -1.39124739e-16,
#          6.61403035e-18,  2.18492437e-17,  9.19691707e-17,
#          5.10883974e-17, -1.08730389e-17, -2.02550930e-16,
#          9.90673446e-17,  8.04332600e-17],
#        [-1.07291246e-17,  6.55874388e-16,  8.18227055e-16,
#          1.00000000e+00,  7.97623683e-16,  1.34649209e-15,
#          9.64524960e-16,  4.83573486e-16,  3.66555034e-16,
#          2.41552180e-16,  8.99800716e-17,  1.11116433e-16,
#          1.25103154e-16, -4.50920814e-17, -1.73647534e-16,
#          1.09289708e-16,  1.29230488e-17,  3.05898720e-17,
#          1.59615995e-17,  4.36639487e-17],
#        [-1.57577430e-17, -5.15250981e-16,  1.24805874e-15,
#          7.97623683e-16,  1.00000000e+00,  6.65941130e-16,
#          7.60742554e-16, -8.00439478e-16, -2.51509218e-16,
#          4.01661715e-17, -1.55130639e-16, -1.86936652e-17,
#         -2.84296496e-16, -5.90922798e-17,  2.76583914e-17,
#         -4.05696077e-17, -6.18271616e-17,  6.16762829e-17,
#         -9.16305230e-17, -1.44357832e-16],
#        [ 3.43485537e-18,  4.24761539e-16, -6.74104899e-16,
#          1.34649209e-15,  6.65941130e-16,  1.00000000e+00,
#          5.79338206e-16,  1.02232277e-15,  1.88243067e-16,
#          1.89218228e-16, -7.71126131e-17, -1.64416250e-16,
#         -5.69692098e-16,  1.56551754e-17,  1.32602070e-16,
#         -2.25936319e-17, -1.69140385e-16, -1.34087460e-16,
#         -3.10277723e-19,  6.78551005e-17],
#        [ 2.24762741e-18, -5.58871726e-16, -7.32352285e-16,
#          9.64524960e-16,  7.60742554e-16,  5.79338206e-16,
#          1.00000000e+00, -6.84471302e-16, -2.99646227e-16,
#          8.45408779e-17,  5.93326159e-17,  2.47833388e-16,
#          1.92664476e-17, -5.54794798e-17, -9.67128755e-17,
#          9.03643459e-17,  8.08393639e-17,  5.67096550e-17,
#         -2.17462052e-17, -8.06489676e-17],
#        [ 6.07555073e-18,  6.48378254e-16,  1.08098418e-16,
#          4.83573486e-16, -8.00439478e-16,  1.02232277e-15,
#         -6.84471302e-16,  1.00000000e+00, -2.06935937e-16,
#          3.37320832e-17,  8.23807978e-17,  6.95272441e-17,
#         -2.04743389e-16,  2.52192545e-17, -1.39342872e-17,
#          2.82401566e-17, -9.17052152e-17, -9.82703169e-17,
#         -2.74078024e-19,  2.04605474e-17],
#        [ 9.77615957e-19,  1.56167180e-18,  2.13749445e-16,
#          3.66555034e-16, -2.51509218e-16,  1.88243067e-16,
#         -2.99646227e-16, -2.06935937e-16,  1.00000000e+00,
#         -8.45995970e-16,  2.85068065e-16, -6.82366400e-16,
#          3.33068641e-17, -2.73907170e-16, -1.68159042e-16,
#         -1.06998070e-16, -1.18067592e-16,  2.22859634e-16,
#          1.94039879e-16, -1.68202059e-16],
#        [-2.56611868e-18,  3.52322036e-17, -3.94504740e-16,
#          2.41552180e-16,  4.01661715e-17,  1.89218228e-16,
#          8.45408779e-17,  3.37320832e-17, -8.45995970e-16,
#          1.00000000e+00, -5.22920546e-16,  1.36942152e-16,
#          6.13156580e-16,  6.75024348e-17,  1.59733796e-16,
#         -1.43017970e-16,  2.23012750e-16, -5.15484873e-16,
#          2.62201026e-16,  1.81669304e-16],
#        [ 5.41268488e-18,  4.19028045e-17,  1.47922859e-16,
#          8.99800716e-17, -1.55130639e-16, -7.71126131e-17,
#          5.93326159e-17,  8.23807978e-17,  2.85068065e-16,
#         -5.22920546e-16,  1.00000000e+00, -4.78372509e-16,
#         -2.01445988e-16, -2.14640849e-16,  2.21277578e-16,
#         -2.58137236e-16, -1.80771278e-16, -5.56201951e-16,
#          1.95658331e-16, -2.93715586e-16],
#        [ 6.61143461e-18, -1.89779195e-17, -1.39124739e-16,
#          1.11116433e-16, -1.86936652e-17, -1.64416250e-16,
#          2.47833388e-16,  6.95272441e-17, -6.82366400e-16,
#          1.36942152e-16, -4.78372509e-16,  1.00000000e+00,
#          3.53785274e-16,  2.79706901e-17,  7.73302849e-17,
#          4.09399161e-16, -5.57945749e-16,  1.97246547e-16,
#         -1.27724733e-16,  1.96863057e-16],
#        [-8.03606730e-18, -2.14082263e-17,  6.61403035e-18,
#          1.25103154e-16, -2.84296496e-16, -5.69692098e-16,
#          1.92664476e-17, -2.04743389e-16,  3.33068641e-17,
#          6.13156580e-16, -2.01445988e-16,  3.53785274e-16,
#          1.00000000e+00,  8.26761295e-17,  3.58016860e-16,
#         -1.16156672e-18, -1.58865946e-16, -6.82975099e-16,
#          2.42448226e-16,  4.38486888e-16],
#        [-2.87270573e-19,  1.32186544e-17,  2.18492437e-17,
#         -4.50920814e-17, -5.90922798e-17,  1.56551754e-17,
#         -5.54794798e-17,  2.52192545e-17, -2.73907170e-16,
#          6.75024348e-17, -2.14640849e-16,  2.79706901e-17,
#          8.26761295e-17,  1.00000000e+00,  5.56866742e-16,
#          3.49266611e-16,  2.09605924e-16, -3.46434267e-16,
#          7.38856449e-16,  5.30202424e-16],
#        [-9.45588994e-18,  9.84460028e-19,  9.19691707e-17,
#         -1.73647534e-16,  2.76583914e-17,  1.32602070e-16,
#         -9.67128755e-17, -1.39342872e-17, -1.68159042e-16,
#          1.59733796e-16,  2.21277578e-16,  7.73302849e-17,
#          3.58016860e-16,  5.56866742e-16,  1.00000000e+00,
#          1.40042478e-16, -4.38800784e-16, -6.95089482e-16,
#          3.14553619e-16,  9.79379794e-17],
#        [-5.91701317e-19, -8.88288223e-18,  5.10883974e-17,
#          1.09289708e-16, -4.05696077e-17, -2.25936319e-17,
#          9.03643459e-17,  2.82401566e-17, -1.06998070e-16,
#         -1.43017970e-16, -2.58137236e-16,  4.09399161e-16,
#         -1.16156672e-18,  3.49266611e-16,  1.40042478e-16,
#          1.00000000e+00, -4.55094280e-16,  8.25429703e-17,
#         -4.08311862e-16,  1.75725191e-16],
#        [ 9.16870979e-19, -1.28087483e-18, -1.08730389e-17,
#          1.29230488e-17, -6.18271616e-17, -1.69140385e-16,
#          8.08393639e-17, -9.17052152e-17, -1.18067592e-16,
#          2.23012750e-16, -1.80771278e-16, -5.57945749e-16,
#         -1.58865946e-16,  2.09605924e-16, -4.38800784e-16,
#         -4.55094280e-16,  1.00000000e+00,  7.73153844e-16,
#          5.37217885e-16, -3.81191309e-16],
#        [-8.70382974e-18, -3.15582871e-17, -2.02550930e-16,
#          3.05898720e-17,  6.16762829e-17, -1.34087460e-16,
#          5.67096550e-17, -9.82703169e-17,  2.22859634e-16,
#         -5.15484873e-16, -5.56201951e-16,  1.97246547e-16,
#         -6.82975099e-16, -3.46434267e-16, -6.95089482e-16,
#          8.25429703e-17,  7.73153844e-16,  1.00000000e+00,
#         -1.36472506e-15, -3.14479378e-17],
#        [ 1.02238837e-17, -4.14971980e-18,  9.90673446e-17,
#          1.59615995e-17, -9.16305230e-17, -3.10277723e-19,
#         -2.17462052e-17, -2.74078024e-19,  1.94039879e-16,
#          2.62201026e-16,  1.95658331e-16, -1.27724733e-16,
#          2.42448226e-16,  7.38856449e-16,  3.14553619e-16,
#         -4.08311862e-16,  5.37217885e-16, -1.36472506e-15,
#          1.00000000e+00,  2.32084275e-16],
#        [-2.85556644e-18, -1.50608918e-17,  8.04332600e-17,
#          4.36639487e-17, -1.44357832e-16,  6.78551005e-17,
#         -8.06489676e-17,  2.04605474e-17, -1.68202059e-16,
#          1.81669304e-16, -2.93715586e-16,  1.96863057e-16,
#          4.38486888e-16,  5.30202424e-16,  9.79379794e-17,
#          1.75725191e-16, -3.81191309e-16, -3.14479378e-17,
#          2.32084275e-16,  1.00000000e+00]])

# %%
# Extract unique user IDs and track IDs
unique_user_ids = data['user_id'].unique()
unique_track_ids = data['track_id'].unique()

# Create a mapping from user and track IDs to indices
user_id_to_index_mapping = {user_id: index for index, user_id in enumerate(unique_user_ids)}
index_to_track_id_mapping = {index: track_id for index, track_id in enumerate(unique_track_ids)}


# Select a random user ID from the unique user IDs
random_user_id = random.choice(unique_user_ids)

# Use the selected user ID to get the index
user_index = user_id_to_index_mapping[random_user_id]

def get_user_recommendations(user_id, user_features, track_similarity_matrix, top_k=5):
    # reduced features for the user
    user_profile = user_features[user_id]

    # calculate similarity of this user to all tracks
    similarity_scores = cosine_similarity([user_profile], track_similarity_matrix)[0]

    # top K track indices with highest similarity scores
    top_track_indices = similarity_scores.argsort()[-top_k:][::-1]

    # map indices to original track IDs
    top_track_ids = [index_to_track_id_mapping[index] for index in top_track_indices]

    return top_track_ids



# Get recommendations for the randomly selected user
recommended_track_ids = get_user_recommendations(user_index, lower_dimensional_features, track_similarity.T)
print("Recommendations for user", random_user_id, ":", recommended_track_ids)
# Out:
# Recommendations for user 859083768 : ['fb45503a9e3596197fa64bd4649e8f78', 'b8dc623f5b936f9959e648323f061b3a', 'da3110a77b724072b08f231c9d6f7534', 'ba84d88c10fb0e42d4754a27ead10546', '33f95122281f76e7134f9cbea3be980f']
